# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("2015_2022_daily data.csv")
data.head()
# Out:
#          Date     Price      Open      High       Low Vol. Change %
# 0  20-04-2022  2,373.00  2,373.00  2,373.00  2,373.00  NaN    3.13%
# 1  19-04-2022  2,301.00  2,301.00  2,301.00  2,301.00  NaN    2.22%
# 2  18-04-2022  2,251.00  2,251.00  2,251.00  2,251.00  NaN    2.23%
# 3  14-04-2022  2,202.00  2,202.00  2,202.00  2,202.00  NaN    0.00%
# 4  13-04-2022  2,202.00  2,202.00  2,202.00  2,202.00  NaN    0.00%

# %%
data.describe()
# Out:
#               Date     Price      Open      High       Low   Vol. Change %
# count         1629      1629      1629      1629      1629   1056     1629
# unique        1629       601       587       580       602    330      383
# top     20-05-2015  1,778.00  1,855.00  1,855.00  1,855.00  0.01K    0.00%
# freq             1        17        22        21        18     48      254

# %% [markdown]
# ### Miscellanous

# %%
datasets = {'india_daily': [(2, 2)], 'india_weekly': [(22, 1)], 'india_monthly': [(9, 8)], 'us_daily': [(17, 16)], 'us_weekly':[(19, 19)], 'us_monthly': [(13, 13)]}

# %%
for df, param in datasets.items():
    for p, q in param:
        print(df, p, q)
        result, _, _ = model(eval(df), p, q)
        print(result)
        print('\n\n\n')
        print('*'*100)
# Out:
# india_daily 2 2
#                         Constant Mean - GARCH Model Results
# ...
# Dep. Variable:     Daily Change (%) Squared   R-squared:                       0.000
# Mean Model:                   Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                            GARCH   Log-Likelihood:               -4117.86
# Distribution:                        Normal   AIC:                           8247.72
# Method:                  Maximum Likelihood   BIC:                           8280.09
#                                               No. Observations:                 1629
# Date:                      Fri, Sep 27 2024   Df Residuals:                     1628
# Time:                              18:03:43   Df Model:                            1
#                                  Mean Model
# ...
#                  coef    std err          t      P>|t|     95.0% Conf. Int.
# ---------------------------------------------------------------------------
# ...
